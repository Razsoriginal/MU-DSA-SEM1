# %%
# Import Libraries
import pandas as pd
import numpy as np

# Import datasets
dataset = pd.read_csv("C:/Users/swapn/OneDrive/Desktop/MSC[CC]/Sem I/DSA/Dataset/melb_data.csv")

# Load Data 
df = pd.DataFrame(dataset)

# check data type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Shape
df.shape
# Out:
# (13580, 21)

# %%
#drop columns
dataset_2 = df.drop(['Rooms'], axis=1)
dataset_2.shape
# Out:
# (13580, 20)

# %%
# concat datasets
dataset_2 = pd.read_csv("C:/Users/swapn/OneDrive/Desktop/MSC[CC]/Sem I/DSA/Dataset/automobile.csv")
# Combine datasets side by side (since no common key exists)
combined_data = pd.concat([df, dataset_2], axis=1)
print(combined_data.shape)
# Out:
# (2059, 50)

# %%
#Sort
dataset_3 = combined_data.sort_values(by=['diesel'])
dataset_3.head()
# Out:
#         Make                                              Model    Price  \
# 0      Honda                                Amaze 1.2 VX i-VTEC   505000
# 126  Hyundai        Grand i10 Sportz 1.2 Kappa VTVT [2013-2016]   375000
# 127     Tata                                   Nexon EV XZ Plus  1375000
# 128  Hyundai  Creta SX (O) 1.4 Turbo 7 DCT Dual Tone [2022-2...  1875000
# 129     Audi                  Q2 Premium Plus I 40 TFSI quattro  2950000
#
#      Year  Kilometer Fuel Type Transmission   Location  Color  Owner  ...  \
# 0    2017      87150    Petrol       Manual       Pune   Grey  First  ...
# 126  2015      87500    Petrol       Manual    Gurgaon   Grey  First  ...
# 127  2021      16000  Electric    Automatic     Mumbai  White  First  ...
# 128  2022      18000    Petrol    Automatic      Delhi  Black  First  ...
# 129  2020      10700    Petrol    Automatic  Ahmedabad  White  First  ...
#
#     compression-ratio  horsepower     peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
# Concatenate
final_data = pd.concat([combined_data, dataset_3])
final_data.shape
# Out:
# (4118, 50)

# %%
# Statistical summary of data
summary = final_data.describe()
print(summary)
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  4.118000e+03  4118.000000  4.118000e+03  3990.000000  3990.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419587e+06     3.363155  5.735475e+04   442.403043   135.248869
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.750000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity  Mileage In mpl  \
# count  3990.000000       3990.000000         3892.000000     4118.000000
# mean   1591.735338          5.306266           52.002210    18648.067023
# std     136.056899          0.822067           15.108256     5128.539980
# ...

# %%
# Skewness
skewness = final_data.skew()
print("Skewness:")
print(skewness)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1232, in nanskew(values, axis, skipna, mask)
#    1231 if values.dtype.kind != "f":
# -> 1232     values = values.astype("f8")
# ...

# %%
import pandas as pd

# Skewness
numeric_data = final_data.select_dtypes(include=['number'])
# Compute skewness
skewness = numeric_data.skew()
print("Skewness (numeric columns only):")
print(skewness)
# Out:
# Skewness (numeric columns only):
# Price                  4.963333
# Year                  -0.840378
# Kilometer             20.973072
# Length                -0.021515
# Width                  0.308219
# Height                 0.837465
# Seating Capacity       1.467530
# Fuel Tank Capacity     0.852674
# Mileage In mpl        -1.245194
# symboling              0.196629
# normalized-losses      0.843366
# wheel-base             1.027387
# length                 0.153866
# width                  0.871742
# height                 0.029064
# curb-weight            0.703152
# engine-size            1.971708
# bore                  -0.032607
# stroke                -0.691119
# compression-ratio      2.574753
# horsepower             1.142210
# peak-rpm               0.107365
# city-mpg               0.677877
# highway-mpg            0.547443
# price                  1.802876
# city-L/100km           0.590158
# diesel                 2.685943
# gas                   -2.685943
# ...

# %%
import pandas as pd

# Select only numeric columns for correlation
numeric_data = final_data.select_dtypes(include=['number'])
# Compute the correlation matrix
correlation_matrix = numeric_data.corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                        Price      Year  Kilometer    Length     Width  \
# Price               1.000000  0.311400  -0.150825  0.556741  0.563996
# Year                0.311400  1.000000  -0.296547  0.098770  0.195493
# Kilometer          -0.150825 -0.296547   1.000000  0.047705  0.017462
# Length              0.556741  0.098770   0.047705  1.000000  0.807054
# Width               0.563996  0.195493   0.017462  0.807054  1.000000
# Height              0.075080  0.116102   0.093592  0.185451  0.296702
# Seating Capacity   -0.038524 -0.006366   0.125244  0.295149  0.221689
# Fuel Tank Capacity  0.584631  0.064512   0.055975  0.813010  0.793868
# Mileage In mpl      0.007486  0.003207   0.013057 -0.039830 -0.029547
# symboling          -0.000036  0.053313   0.015490 -0.058809 -0.056684
# normalized-losses   0.001068  0.103074  -0.166011 -0.115061 -0.152592
# wheel-base         -0.003361  0.014108  -0.000548  0.092534  0.100676
# ...

# %%
# Dealing with Missing values
data_without_missing_rows = df.dropna()
# Remove columns with any missing values
data_without_missing_columns = df.dropna(axis=1)
data_without_missing_columns.shape
# Out:
# (2059, 12)

# %%
df.replace(999, 0, inplace=True)

# %%
df['Year'] = pd.to_numeric(df['Year'])
df.describe()
# Out:
#               Price         Year     Kilometer       Length        Width  \
# count  2.059000e+03  2059.000000  2.059000e+03  1995.000000  1995.000000
# mean   1.702992e+06  2016.425449  5.422471e+04  4280.860652  1767.991980
# std    2.419881e+06     3.363564  5.736172e+04   442.458507   135.265825
# min    4.900000e+04  1988.000000  0.000000e+00  3099.000000  1475.000000
# 25%    4.849990e+05  2014.000000  2.900000e+04  3985.000000  1695.000000
# 50%    8.250000e+05  2017.000000  5.000000e+04  4370.000000  1770.000000
# 75%    1.925000e+06  2019.000000  7.200000e+04  4629.000000  1831.500000
# max    3.500000e+07  2022.000000  2.000000e+06  5569.000000  2220.000000
#
#             Height  Seating Capacity  Fuel Tank Capacity  Mileage In mpl
# count  1995.000000       1995.000000         1946.000000     2059.000000
# mean   1591.735338          5.306266           52.002210    18648.067023
# std     136.073956          0.822170           15.110198     5129.162943
# ...

# %%
df['Price_scaled'] = df['Price'] / df['Price'].max()
print(df['Price_scaled'])
# Out:
# 0       0.014429
# 1       0.012857
# 2       0.006286
# 3       0.022829
# 4       0.055714
#           ...
# 2054    0.024286
# 2055    0.007857
# 2056    0.006857
# 2057    0.122571
# 2058    0.019143
# Name: Price_scaled, Length: 2059, dtype: float64

# %%
df['Price_scaled'] = (df['Price'] - df['Price'].min()) / (df['Price'].max() - df['Price'].min())
print(df['Price_scaled'])
# Out:
# 0       0.013047
# 1       0.011473
# 2       0.004893
# 3       0.021459
# 4       0.054390
#           ...
# 2054    0.022918
# 2055    0.006466
# 2056    0.005465
# 2057    0.121341
# 2058    0.017768
# Name: Price_scaled, Length: 2059, dtype: float64

# %%
df['Price_scaled'] = (df['Price'] - df['Price'].mean()) /df['Price'].std()
print(df['Price_scaled'])
# Out:
# 0      -0.495062
# 1      -0.517791
# 2      -0.612837
# 3      -0.373569
# 4       0.102075
#           ...
# 2054   -0.352493
# 2055   -0.590108
# 2056   -0.604572
# 2057    1.069064
# 2058   -0.426877
# Name: Price_scaled, Length: 2059, dtype: float64

# %%
bins = np.linspace(min(df['Price']), max(df['Price']), num=4)
group_names = ['Low', 'Medium', 'High']
df['price_binned'] = pd.cut(df['Price'], bins, labels=group_names, include_lowest=True)


import matplotlib.pyplot as plt

df['Price'].hist(bins=3, color='blue', alpha=0.7)
plt.grid(True)

# %%
pd.get_dummies(df["Year"])
# Out:
#        1988   1996   2000   2002   2004   2006   2007   2008   2009   2010  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2054  False  False  False  False  False  False  False  False  False  False
# 2055  False  False  False  False  False  False  False  False  False  False
# 2056  False  False  False  False  False  False  False  False  False  False
# 2057  False  False  False  False  False  False  False  False  False  False
# 2058  False  False  False  False  False  False  False  False  False  False
#
# ...
