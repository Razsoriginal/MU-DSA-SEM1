# %%
data_without_missing_rows = df.dropna()


# Remove columns with any missing values
data_without_missing_columns = df.dropna(axis=1)
data_without_missing_columns.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_without_missing_rows = df.dropna()
#       4 # Remove columns with any missing values
#       5 data_without_missing_columns = df.dropna(axis=1)
#
# NameError: name 'df' is not defined
